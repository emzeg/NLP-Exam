# %%
# !pip install vaderSentiment
# !pip install nltk

# %%
import nltk
import string
import re
import collections
import numpy as np
from nltk.tokenize import word_tokenize, sent_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu
from scipy.stats import kruskal
import scipy.stats as stats
from collections import Counter

# Download NLTK data (if needed)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/ucloud/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/ucloud/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/ucloud/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Define a function to read in text files
def read_text_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.read()

# Example text file loading
text_1400s = [
    read_text_from_file('malleus_maleficarum-1487.txt'),
    read_text_from_file('Innocent_VIII_BULL_Summis_desiderantes_1484.txt'),
    read_text_from_file('Johannes_Nider_the_ANT HILL_circa_1437.txt')
]

text_1500s = [
    read_text_from_file('defense_of_witchcraft_16th_century.txt'),
    read_text_from_file('The Discoverie of Witchcraft 1584.txt')
]

text_1600s = [
    read_text_from_file('Village_Mohra_1669_1670.txt'),
    read_text_from_file('Malmoe_boy_1678.txt'),
    read_text_from_file('A Treatise of Witchcraft 1616.txt')
]

# %%
# Define stopwords for preprocessing
stop_words = set(nltk.corpus.stopwords.words('english'))

# Preprocess function to clean and tokenize text
def preprocess_text(text):
    # Tokenize the text and remove punctuation and stopwords
    tokens = word_tokenize(text.lower())  # Tokenize and convert to lowercase
    tokens = [word for word in tokens if word not in string.punctuation and word not in stop_words]
    return ' '.join(tokens)  # Return cleaned text

# Preprocess texts for each time period
text_1400s_preprocessed = [preprocess_text(text) for text in text_1400s]
text_1500s_preprocessed = [preprocess_text(text) for text in text_1500s]
text_1600s_preprocessed = [preprocess_text(text) for text in text_1600s]

# %%
# Initialize the VADER sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Function to get sentiment score using VADER
def get_sentiment_vader(text):
    sentiment_score = analyzer.polarity_scores(text)
    return sentiment_score['compound']  # Compound score indicates overall sentiment

# Function to analyze sentiment for the word 'witch' across texts using VADER
def analyze_sentiment_for_word_vader(texts, word='witch'):
    sentiments = []
    
    for text in texts:
        sentences = nltk.sent_tokenize(text)  # Tokenize the text into sentences
        word_sentiments = []
        
        for sentence in sentences:
            if word in sentence.lower():  # Check if the word appears in the sentence
                compound = get_sentiment_vader(sentence)  # Get compound sentiment score
                word_sentiments.append(compound)  # Store the compound score
        
        # Take the average sentiment for the text
        if word_sentiments:
            sentiments.append(np.mean(word_sentiments))  # Average compound score for the text
        else:
            sentiments.append(0)  # Default to 0 if the word is not mentioned in the text
    
    # Calculate the average sentiment across all texts
    average_sentiment = np.mean(sentiments)
    
    return sentiments, average_sentiment

# %%
# Function to get the frequency of the word 'witch' (or related words)
def get_word_frequency(texts, word='witch'):
    vectorizer = CountVectorizer(stop_words='english')
    X = vectorizer.fit_transform(texts)
    
    # Get the index of the word 'witch' in the feature matrix
    word_index = vectorizer.get_feature_names_out().tolist().index(word)
    
    # Count the occurrences of 'witch' in each text
    word_counts = X[:, word_index].toarray()
    
    return word_counts.sum()

# %%
# Analyze compound score for the word 'witch' across different time periods
sentiments_1400s, avg_sentiment_1400s = analyze_sentiment_for_word_vader(text_1400s_preprocessed, word='witch')
sentiments_1500s, avg_sentiment_1500s = analyze_sentiment_for_word_vader(text_1500s_preprocessed, word='witch')
sentiments_1600s, avg_sentiment_1600s = analyze_sentiment_for_word_vader(text_1600s_preprocessed, word='witch')

# Get word frequency for 'witch' across different time periods
witch_frequency_1400s = get_word_frequency(text_1400s_preprocessed, word='witch')
witch_frequency_1500s = get_word_frequency(text_1500s_preprocessed, word='witch')
witch_frequency_1600s = get_word_frequency(text_1600s_preprocessed, word='witch')

# Print contextualized output for each time period

# For the 1400s
print(f"\nSentiment Analysis for 'witch' in the 1400s:")
for i, sentiment in enumerate(sentiments_1400s, 1):
    print(f"  Text {i}: Sentiment = {sentiment:.3f}")

print(f"Total 'witch' frequency in the 1400s: {witch_frequency_1400s}")
print(f"Average compound score for the word 'witch' in the 1400s: {avg_sentiment_1400s:.3f}")

# For the 1500s
print(f"\nSentiment Analysis for 'witch' in the 1500s:")
for i, sentiment in enumerate(sentiments_1500s, 1):
    print(f"  Text {i}: Sentiment = {sentiment:.3f}")

print(f"Total 'witch' frequency in the 1500s: {witch_frequency_1500s}")
print(f"Average compound score for the word 'witch' in the 1500s: {avg_sentiment_1500s:.3f}")

# For the 1600s
print(f"\nSentiment Analysis for 'witch' in the 1600s:")
for i, sentiment in enumerate(sentiments_1600s, 1):
    print(f"  Text {i}: Sentiment = {sentiment:.3f}")

print(f"Total 'witch' frequency in the 1600s: {witch_frequency_1600s}")
print(f"Average compound score for the word 'witch' in the 1600s: {avg_sentiment_1600s:.3f}")
# Out:
# Sentiment Analysis for 'witch' in the 1400s:
#   Text 1: Sentiment = -0.546
#   Text 2: Sentiment = 0.000
#   Text 3: Sentiment = -0.743
# Total 'witch' frequency in the 1400s: 404
# Average compound score for the word 'witch' in the 1400s: -0.430
#
# Sentiment Analysis for 'witch' in the 1500s:
#   Text 1: Sentiment = -0.018
#   Text 2: Sentiment = 0.683
# Total 'witch' frequency in the 1500s: 313
# Average compound score for the word 'witch' in the 1500s: 0.333
#
# Sentiment Analysis for 'witch' in the 1600s:
#   Text 1: Sentiment = -1.000
#   Text 2: Sentiment = 0.942
#   Text 3: Sentiment = 1.000
# Total 'witch' frequency in the 1600s: 32
# Average compound score for the word 'witch' in the 1600s: 0.314

# %%
print(sentiments_1400s)
print(witch_frequency_1600s)
# Out:
# ([np.float64(-0.5462793388429751), 0, np.float64(-0.743)], np.float64(-0.42975977961432504))
# 32

# %%
year1400s = stats.shapiro(sentiments_1400s) #normal
year1500s = stats.shapiro(sentiments_1500s) # not normal
year1600s = stats.shapiro(sentiments_1600s) #not normal


yearword1400s = stats.shapiro(witch_frequency_1400s) #not normal
yearword1500s = stats.shapiro(witch_frequency_1500s) # not normal
yearword1600s = stats.shapiro(witch_frequency_1600s) #not normal


print(year1400s, year1500s, year1600s)

#all are not normal so we can not use ANOVA
print(yearword1400s, yearword1500s, yearword1600s)

#all are not normal so we can not use ANOVA
# Out:
# ShapiroResult(statistic=np.float64(nan), pvalue=np.float64(nan)) ShapiroResult(statistic=np.float64(nan), pvalue=np.float64(nan)) ShapiroResult(statistic=np.float64(nan), pvalue=np.float64(nan))
# /tmp/ipykernel_2036/204630371.py:2: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   year1500s = stats.shapiro(sentiments_1500s) # not normal
# /tmp/ipykernel_2036/204630371.py:6: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   yearword1400s = stats.shapiro(witch_frequency_1400s) #normal
# /tmp/ipykernel_2036/204630371.py:7: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   yearword1500s = stats.shapiro(witch_frequency_1500s) # not normal
# ...

# %%
#significance of sentiment across dif time periods 


h_statistic, p_value = kruskal(sentiments_1400s, sentiments_1500s, sentiments_1600s)

print(f"Kruskal-Wallis H-statistic: {h_statistic}")
print(f"P-value: {p_value}")

#P is not significant, there is no significance between the sentiments of the word witch
# Out:
# Kruskal-Wallis H-statistic: 1.1111111111111143
# P-value: 0.573753420737432

# %%
#significance of sentiment across dif time periods 


h_statistic, p_value = kruskal(witch_frequency_1400s, witch_frequency_1500s, witch_frequency_1600s)

print(f"Kruskal-Wallis H-statistic: {h_statistic}")
print(f"P-value: {p_value}")

#P is not significant, there is no significance between the sentiments of the word witch
# Out:
# Kruskal-Wallis H-statistic: 2.0
# P-value: 0.36787944117144245

# %%
# Plot sentiment over time
time_periods = ['1400s', '1500s', '1600s']
sentiments = [sum(sentiments_1400s)/len(sentiments_1400s), 
              sum(sentiments_1500s)/len(sentiments_1500s), 
              sum(sentiments_1600s)/len(sentiments_1600s)]

# Plot word frequency over time
witch_frequencies = [witch_frequency_1400s, witch_frequency_1500s, witch_frequency_1600s]

# Create figure and axis for plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot sentiment
ax1.plot(time_periods, sentiments, color='blue', marker='o', label='Sentiment')
ax1.set_xlabel('Time Period')
ax1.set_ylabel('Sentiment', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create second y-axis for frequency
ax2 = ax1.twinx()
ax2.plot(time_periods, witch_frequencies, color='red', marker='s', label='Frequency')
ax2.set_ylabel('Word Frequency', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add title and show the plot
plt.title("Sentiment and Frequency of 'Witch' Over Time")
fig.tight_layout()  # Adjust layout
plt.show()

# %%
import nltk
import numpy as np

# Function to calculate normalized frequency (TF) of "witch" in a given text
def calculate_normalized_frequency(text, word="witch"):
    words = nltk.word_tokenize(text.lower())  # Tokenize and lower case
    total_words = len(words)
    word_count = words.count(word.lower())  # Count occurrences of "witch"
    return word_count / total_words if total_words > 0 else 0

# Calculate the average sentiment for each time period
average_sentiment_1400s = np.mean(sentiments_1400s) if sentiments_1400s else 0
average_sentiment_1500s = np.mean(sentiments_1500s) if sentiments_1500s else 0
average_sentiment_1600s = np.mean(sentiments_1600s) if sentiments_1600s else 0

# Normalize frequencies for each time period
normalized_frequency_1400s = [calculate_normalized_frequency(text, "witch") for text in text_1400s]
normalized_frequency_1500s = [calculate_normalized_frequency(text, "witch") for text in text_1500s]
normalized_frequency_1600s = [calculate_normalized_frequency(text, "witch") for text in text_1600s]

# Calculate the average normalized frequency per time period
average_normalized_frequency_1400s = np.mean(normalized_frequency_1400s) if normalized_frequency_1400s else 0
average_normalized_frequency_1500s = np.mean(normalized_frequency_1500s) if normalized_frequency_1500s else 0
average_normalized_frequency_1600s = np.mean(normalized_frequency_1600s) if normalized_frequency_1600s else 0

# Print results for normalized frequency and sentiment
def print_normalized_results(time_periods, sentiments, frequencies):
    print("Normalized Sentiment and Frequency of the word 'witch' over Time Periods:")
    for time_period, sentiment, frequency in zip(time_periods, sentiments, frequencies):
        print(f"\n{time_period}:")
        print(f"Average Sentiment Score: {sentiment:.4f}")
        print(f"Average Normalized Frequency of 'witch': {frequency:.4f}")

# Time periods
time_periods = ['1400s', '1500s', '1600s']
sentiments = [average_sentiment_1400s, average_sentiment_1500s, average_sentiment_1600s]
frequencies = [average_normalized_frequency_1400s, average_normalized_frequency_1500s, average_normalized_frequency_1600s]

# Print the results
print_normalized_results(time_periods, sentiments, frequencies)
# Out:
# Normalized Sentiment and Frequency of the word 'witch' over Time Periods:
#
# 1400s:
# Average Sentiment Score: -0.4298
# Average Normalized Frequency of 'witch': 0.0014
#
# 1500s:
# Average Sentiment Score: 0.3326
# Average Normalized Frequency of 'witch': 0.0008
#
# 1600s:
# Average Sentiment Score: 0.3138
# Average Normalized Frequency of 'witch': 0.0003

# %%
h_statistic, p_value = kruskal(normalized_frequency_1400s, normalized_frequency_1500s, normalized_frequency_1600s)

print(f"Kruskal-Wallis H-statistic: {h_statistic}")
print(f"P-value: {p_value}")
# Out:
# Kruskal-Wallis H-statistic: 2.248995983935742
# P-value: 0.3248154864196296
# /tmp/ipykernel_2036/1065277060.py:2: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   stats.shapiro(normalized_frequency_1500s) # not normal

# %%
# Data for the time periods, sentiment, and normalized frequency
time_periods = ['1400s', '1500s', '1600s']
sentiments = [average_sentiment_1400s, average_sentiment_1500s, average_sentiment_1600s]
frequencies = [average_normalized_frequency_1400s, average_normalized_frequency_1500s, average_normalized_frequency_1600s]

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot sentiment data
color = 'tab:red'
ax1.set_xlabel('Time Period')
ax1.set_ylabel('Average Sentiment Score', color="hotpink")
ax1.plot(time_periods, sentiments, color="hotpink", marker='o', label='Sentiment', linestyle='-', linewidth=2)
ax1.tick_params(axis='y', labelcolor="hotpink")

# Create a second y-axis for normalized frequency
ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Average Normalized Frequency', color="lightgreen")
ax2.plot(time_periods, frequencies, color="lightgreen", marker='o', label='Frequency', linestyle='--', linewidth=2)
ax2.tick_params(axis='y', labelcolor="lightgreen")

# Add a title
plt.title("Average Sentiment and Normalized Frequency of the word 'Witch' Over Time")

# Show the plot
fig.tight_layout()
plt.show()
